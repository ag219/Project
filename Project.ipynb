# %%
import pandas as pd

# %%
athlete_events = pd.read_csv('C:/Users/agalf/Downloads/athlete_events.csv')

# %%
regions = pd.read_csv('C:/Users/agalf/Downloads/noc_regions.csv')

# %%
regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
regions.tail()
# Out:
#      NOC    region        notes
# 225  YEM     Yemen          NaN
# 226  YMD     Yemen  South Yemen
# 227  YUG    Serbia   Yugoslavia
# 228  ZAM    Zambia          NaN
# 229  ZIM  Zimbabwe          NaN

# %%
len(regions)
# Out:
# 230

# %%
regions.dtypes
# Out:
# NOC       object
# region    object
# notes     object
# dtype: object

# %%
regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
regions.region.hist()
# Out:
# <Axes: >

# %%
regions.head(25)
# Out:
#     NOC                  region                 notes
# 0   AFG             Afghanistan                   NaN
# 1   AHO                 Curacao  Netherlands Antilles
# 2   ALB                 Albania                   NaN
# 3   ALG                 Algeria                   NaN
# 4   AND                 Andorra                   NaN
# 5   ANG                  Angola                   NaN
# 6   ANT                 Antigua   Antigua and Barbuda
# 7   ANZ               Australia           Australasia
# 8   ARG               Argentina                   NaN
# 9   ARM                 Armenia                   NaN
# 10  ARU                   Aruba                   NaN
# 11  ASA          American Samoa                   NaN
# 12  AUS               Australia                   NaN
# 13  AUT                 Austria                   NaN
# 14  AZE              Azerbaijan                   NaN
# 15  BAH                 Bahamas                   NaN
# ...

# %%
athlete_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
len(athlete_events)
# Out:
# 271116

# %%
athlete_events.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
athlete_events.head(50)
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8    5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9    5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10   6                     Per Knut Aaland   M  31.0   188.0    75.0
# 11   6                     Per Knut Aaland   M  31.0   188.0    75.0
# 12   6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
from pandasql import sqldf

# %%
pysqldf = lambda q: sqldf(q, globals())

# %%
pysqldf("SELECT * FROM athlete_events WHERE NOC = 'CRO' AND Medal != 'None'")
# Out:
#          ID             Name Sex   Age  Height  Weight     Team  NOC  \
# 0      2256   Vladan Alanovi   M  25.0   190.0    81.0  Croatia  CRO
# 1      2739    Mirko Alilovi   M  26.0   200.0   110.0  Croatia  CRO
# 2      3659        Mario Ani   M  20.0   195.0    84.0  Croatia  CRO
# 3      4847   Franjo Arapovi   M  27.0   211.0   120.0  Croatia  CRO
# 4      7253       Ivano Bali   M  25.0   190.0    96.0  Croatia  CRO
# ..      ...              ...  ..   ...     ...     ...      ...  ...
# 144  127714     Drago Vukovi   M  21.0   194.0    90.0  Croatia  CRO
# 145  127714     Drago Vukovi   M  28.0   194.0    90.0  Croatia  CRO
# 146  133954  Lucija Zaninovi   F  25.0   170.0    52.0  Croatia  CRO
# 147  135294      Vedran Zrni   M  24.0   188.0    80.0  Croatia  CRO
# 148  135335     Martina Zubi   F  19.0   173.0    55.0  Croatia  CRO
#
#            Games  Year  Season       City       Sport  \
# 0    1992 Summer  1992  Summer  Barcelona  Basketball
# ...

# %%
pysqldf("SELECT * FROM athlete_events WHERE NOC = 'CRO' AND Medal != 'None' AND Sex = 'F'")
# Out:
#         ID             Name Sex   Age  Height  Weight     Team  NOC  \
# 0    62116       Sara Kolak   F  21.0   170.0    74.0  Croatia  CRO
# 1    63093   Janica Kosteli   F  20.0   175.0    76.0  Croatia  CRO
# 2    63093   Janica Kosteli   F  20.0   175.0    76.0  Croatia  CRO
# 3    63093   Janica Kosteli   F  20.0   175.0    76.0  Croatia  CRO
# 4    63093   Janica Kosteli   F  20.0   175.0    76.0  Croatia  CRO
# 5    63093   Janica Kosteli   F  24.0   175.0    76.0  Croatia  CRO
# 6    63093   Janica Kosteli   F  24.0   175.0    76.0  Croatia  CRO
# 7    92783     Snjeana Peji   F  26.0   170.0    75.0  Croatia  CRO
# 8    93475   Sandra Perkovi   F  22.0   183.0    85.0  Croatia  CRO
# 9    93475   Sandra Perkovi   F  26.0   183.0    85.0  Croatia  CRO
# 10  105793       Sandra ari   F  24.0   175.0    67.0  Croatia  CRO
# 11  126975      Blanka Vlai   F  24.0   193.0    71.0  Croatia  CRO
# 12  126975      Blanka Vlai   F  32.0   193.0    71.0  Croatia  CRO
# ...

# %%
pysqldf("SELECT COUNT(*) FROM athlete_events WHERE NOC = 'CRO' AND Medal != 'None' AND Sex = 'M' GROUP BY 'Sport'")
# Out:
#    COUNT(*)
# 0       134

# %%
athlete_events.Age.hist()
# Out:
# <Axes: >

# %%
athlete_events.Sex.hist()
# Out:
# <Axes: >

# %%
athlete_events.Season.hist()
# Out:
# <Axes: >
